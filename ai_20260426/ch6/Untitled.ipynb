# %%
class Animal:
    def __init__(self,name,age):
        self.__name = name
        #私有化
        self.__age = age
    def printInfo(self):        
        print(self.getName(),self.__age)
    def setAge(self,age):
        if age < 0 or age > 200:
            raise OverflowError("錯誤的年齡")
        self.__age = age
    def getAge(self):    
        return self.__age
    def setName(self,name):
        if len(name) < 2 or len(name) > 20:
            raise OverflowError("錯誤的姓名")
        self.__name = name
    def getName(self):    
        return self.__name
#作業name私有化
#name長度不可小於2 不可大於20        
a1 = Animal("Bobo",3)        
a1.printInfo()
a1.setAge(25)
a1.setName("Ken")
a1.printInfo()
# Out:
# Bobo 3
# Ken 25

# %%
class Employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
    def printInfo(self):     
       print(self.name,self.salary)
emp1 = Employee("Ken",26000)       
emp1.printInfo()
emp1.salary += 5000
emp1.name += " Len"
emp1.printInfo()
# Out:
# Ken 26000
# Ken Len 31000

# %%
class Employee:
    def __init__(self,name,salary):
        self.__name = name
        self.__salary = salary
    def printInfo(self):     
       print(self.name,self.salary)
    def setSalary(self,salary):
        self.__salary = salary
    def getSalary(self):
        return self.__salary
    def setName(self,name):     
        self.__name = name
    def getName(self):    
        return self.__name
    #getter
    @property
    def salary(self):
        return self.getSalary()
    @salary.setter    
    def salary(self,salary):    
        self.setSalary(salary)
    @property     
    def name(self):
        return self.getName()
    @name.setter    
    def name(self,name):    
        self.setName(name) 
        
emp1 = Employee("Ken",26000)       
emp1.printInfo()
emp1.salary += 5000
#emp1.setSalary(emp1.getSalary() + 5000)
emp1.name += " Len"
emp1.printInfo()
# Out:
# Ken 26000
# Ken Len 31000

# %% [markdown]
# ## 繼承

# %%
class Animal:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def printInfo(self):    
        print(self.name,self.age)
an = Animal("Bobo",5)        
an.printInfo()
# Out:
# Bobo 5

# %%
class Cat:
    pass
cat1 = Cat()
cat1.printInfo()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 4
#       2     pass
#       3 cat1 = Cat()
# ----> 4 cat1.printInfo()
#
# AttributeError: 'Cat' object has no attribute 'printInfo'

# %%
class Cat(Animal):
    pass
cat1 = Cat("Kiki",5)
cat1.printInfo()
# Out:
# Kiki 5

# %%
class Animal:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def printInfo(self):    
        print(self.name,self.age)
    def run(self):    
        print(self.name,"跑")
    def eat(self):
        print(self.name,"吃")
    
an = Animal("Bobo",5)        
an.printInfo()
an.run()
an.eat()
# Out:
# Bobo 5
# Bobo 跑
# Bobo 吃

# %% [markdown]
# ## 方法覆寫

# %%
class Cat(Animal):
    def accelerate(self):
        print("加速",end="")
        self.run()
cat1 = Cat("Lulu",2)
cat1.accelerate()
# Out:
# 加速Lulu 跑

# %%
class Bird1(Animal):
    def fly(self):
        print("會飛")
    def run(self):#Override
        print("跳跳跑!")
class Bird2(Animal):        
    def fly(self):
        print("不會飛")
    def run(self):
        super().run() #呼叫父類(Animal)的run
        print("跑得很快")
b1 = Bird1("DoDo",2)        
b1.fly()
b1.run()
b2 = Bird2("KoKo",3)
b2.eat()
b2.run()
# Out:
# 會飛
# 跳跳跑!
# KoKo 吃
# KoKo 跑
# 跑得很快

# %% [markdown]
# ## 初始化方法

# %%
class Person:
    def __init__(self,name="ken"):
        self.name = name
    def printInfo(self):    
        print(self.name,"Hello!")
class Student(Person):
    pass
st1 = Student("Vivin")    
st1.printInfo()
# Out:
# Vivin Hello!

# %%
class Teacher(Person):
    def __init__(self,name=""):
        print("Teacher")
        self.name = name
t1 = Teacher("Lucy")        
t1.printInfo()
# Out:
# Teacher
# Lucy Hello!

# %%
class Teacher(Person):
    def __init__(self,name=""):
        print("Teacher")
        super().__init__(name)
t1 = Teacher("Iris")        
t1.printInfo()
# Out:
# Teacher
# Iris Hello!

# %% [markdown]
# ## __str__ 可輸出物件的內容

# %%
class Point:
    def __init__(self,x=0,y=0):
        self.x = x
        self.y = y
p1 = Point(2,3)        
p2 = Point(-1,2)
print(p1)
print(p2)

# %%
class Point:
    def __init__(self,x=0,y=0):
        self.x = x
        self.y = y
    def __str__(self): #將物件轉字串的規則
        return f"({self.x},{self.y})"
p1 = Point(2,3)        
p2 = Point(-1,2)
print(p1)
print(p2)
# Out:
# (2,3)
# (-1,2)

# %% [markdown]
# https://docs.python.org/zh-tw/3/library/operator.html
# ``` python
# __add__  +
#
# __iadd__  +=
#
# __sub__  -
#
# __isub__  -=
#
# __mul__  *
#
# __imul__  *=
#
# __truediv__   /
#
# __itruediv__   /=
#
# __floordiv__  //
#
# __ifloordiv__  //=
#
# __mod__  %
#
# __imod__  %=
#
# __pow__  **
#
# __ipow__  **=
# ```

# %%
class Point:
    def __init__(self,x=0,y=0):
        self.x = x
        self.y = y
    def __str__(self): #將物件轉字串的規則
        return f"({self.x},{self.y})"
    def __add__(self,other): 
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
p1 = Point(2,3)        
p2 = Point(-1,2)
print(p1)
print(p2)
ans = p1 + p2
print(ans)
# Out:
# (2,3)
# (-1,2)
# (1,5)

# %%
class Point:
    def __init__(self,x=0,y=0):
        self.x = x
        self.y = y
    def __str__(self): #將物件轉字串的規則
        return f"({self.x},{self.y})"
    def __add__(self,other): 
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
    def __len__(self):
        my_len = (self.x ** 2) + (self.y ** 2)
        return my_len
    def __lt__(self,other):    
        return len(self) < len(other)
p1 = Point(2,3)        
p2 = Point(-1,2)
print(len(p1))
print(p2)
print(p1 < p2)
print(p1 > p2)
# Out:
# 13
# (-1,2)
# False
# True

# %%
class Employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
    def printInfo(self):     
       print(self.name,self.salary)
    def __str__(self):    
        return f"{self.name}:{self.salary}"
    def __lt__(self,other):    
        return self.salary < other.salary
    def __eq__(self,other):     
        return self.salary == other.salary

emp1 = Employee("Ken",62000)
emp2 = Employee("Iris",36000)
emp3 = Employee("Joy",36000)
print(emp1)
print(emp2)
print(emp1 < emp2)
print(emp1 > emp2)
print(emp1 == emp2)
print(emp2 == emp3)
# Out:
# Ken:62000
# Iris:36000
# False
# True
# False
# True

# %%
class Student:
   def __init__(self,name,score):
        self.name = name
        self.score = score
   def __str__(self):     
       return f"{self.name}:{self.score}"
   def __lt__(self,other):    
      return self.score < other.score  
st1 = Student("Ken",85)      
st2 = Student("Iris",65)      
st3 = Student("Joy",77)      
st4 = Student("Lucy",67)      
st5 = Student("Lindy",32)      
myList = [st1,st2,st3,st4,st5]
myList.sort()

for st in myList:
    print(st)
# Out:
# Lindy:32
# Iris:65
# Lucy:67
# Joy:77
# Ken:85

# %%
class S():
    def method1(self):
        print("S.method1")
    def method2(self):
        print("S.method2")
class Z():
    def method1(self):
         print("Z.method1")
class A(S):
    def method3(self):
        print("A.method3")
class B(Z,S):
    def method2(self):
        print("B.method2")  
    def method3(self):
        print("B.method3")
class C(A,B):        
    def method4(self):
        print("method4")
c = C() 
print(C.mro())
c.method4()
c.method3()
c.method2()
c.method1()
# Out:
# [<class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class '__main__.Z'>, <class '__main__.S'>, <class 'object'>]
# method4
# A.method3
# B.method2
# Z.method1

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\xvpow\ai_20260426\ch6

# %%
import modu
obj1 = modu.Test1()
modu.func1()
# Out:
# Create
# func 1

# %% [markdown]
# # 模組與套件
# 引用 python 檔案就以檔案的主檔案名稱作為模組名稱，
#
# + 共有以下三種方式：
# + import 模組
# + import 模組 as 新模組名稱
# + from 模組 import 模組內方法
#   + 不建議 from 模組 import *，易造成名稱衝突!

# %%
import happy.my_mod
happy.my_mod.happy_python()
# Out:
# Happy Python 1

# %%
import happy.io.my_mod as myio
myio.happy_python()
# Out:
# Happy Python IO2

# %%
from happy.my_mod import happy_python
happy_python()
# Out:
# Happy Python 1

# %% [markdown]
# ## 作業
#
# 設計錢包總金額為 1000 元，
#
# 如果購買商品總金額超過 1000
#
# 會引發一個金額不足的例外 OverflowError

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\xvpow\ai_20260426\ch6
# ['.ipynb_checkpoints', 'happy', 'modu.py', 'Untitled.ipynb', '__pycache__']

# %%
from os import walk 
myPath = "."
for root,dirs,files in walk(myPath):
    print("路徑:",root)
    print(" 目錄:",dirs)
    print(" 檔案:",files)
# Out:
# 路徑: .
#  目錄: ['.ipynb_checkpoints', 'happy', '__pycache__']
#  檔案: ['modu.py', 'Untitled.ipynb']
# 路徑: .\.ipynb_checkpoints
#  目錄: []
#  檔案: ['Untitled-checkpoint.ipynb']
# 路徑: .\happy
#  目錄: ['io', '__pycache__']
#  檔案: ['my_mod.py']
# 路徑: .\happy\io
#  目錄: ['__pycache__']
#  檔案: ['my_mod.py']
# 路徑: .\happy\io\__pycache__
#  目錄: []
#  檔案: ['my_mod.cpython-311.pyc']
# 路徑: .\happy\__pycache__
#  目錄: []
#  檔案: ['my_mod.cpython-311.pyc']
# 路徑: .\__pycache__
#  目錄: []
#  檔案: ['modu.cpython-311.pyc']

# %% [markdown]
# ## 檔案存取
#
# file object = open(file_name [, access_mode])
#
# UTF8 編碼資料還請加入另一個參數才可避免亂碼：encoding=‘utf-8'
# file object = open(file_name [, access_mode])
#
# 參數說明
#
# file_name：file_name 參數是一個字串資料，代表包含要連結的文件名稱。
#
# access_mode：access_mode 確定文件必須打開的模式，包括讀取、寫入、附加等等。稍後會列完整列表。這是可選參數，默認文件訪問模式為讀取(r)。
#
# |模式	|可做操作|若檔案不存在|是否覆蓋|
# |----|--------|-----------|-------|
# |r	|只能讀|報錯	|-|
# |r+	|可讀可寫|報錯|是|
# |w	|只能寫|建立|是|
# |w+ |可讀可寫|建立|是|
# |a　|只能寫|建立|否，追加寫|
# |a+	|可讀可寫|建立|否，追加寫|

# %%
text = """python與中文AAA
1. 我們來試試看中文儲存能力。
2. 許這個字會有編碼衝突風險。
3. 犇這個字必須是utf8編碼才有。
"""
print(text,file=open("data.txt","w",encoding="utf-8"))

# %%
dataList = []
while True:
    score = input("請輸入數字(quit離開)")
    if score == "quit":
        break
    dataList.append(score)    
file = open("score.txt","w",encoding="utf-8")    
file.write(str(dataList))
file.close()
# Out:
# 請輸入數字(quit離開) 99
# 請輸入數字(quit離開) 88
# 請輸入數字(quit離開) 22
# 請輸入數字(quit離開) quit
