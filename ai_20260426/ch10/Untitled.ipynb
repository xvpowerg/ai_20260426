# %% [markdown]
# ## 刪除

# %%
import pandas as pd
d = {'one':pd.Series([1,2,3],index=['a','b','c']),
     'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df1 = pd.DataFrame(d)
print(df1)
df1["three"] = [10,11,12,13]
print(df1)
print("="*10)
print(df1.drop("one",axis=1))
print("="*10)
print(df1.drop("d",axis=0))
print("="*10)
df1.drop("one",axis=1,inplace=True)
print(df1)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
#    one  two  three
# a  1.0    1     10
# b  2.0    2     11
# c  3.0    3     12
# d  NaN    4     13
# ...
#    two  three
# a    1     10
# b    2     11
# c    3     12
# d    4     13
# ...
#    one  two  three
# a  1.0    1     10
# b  2.0    2     11
# c  3.0    3     12
# ...
#    two  three
# a    1     10
# b    2     11
# c    3     12
# d    4     13

# %%
import pandas as pd

d = {
    'A': pd.Series([5, 6, 7], index=['x', 'y', 'z']),
    'B': pd.Series([50, 60, 70, 80], index=['x', 'y', 'z', 'w'])
}
df = pd.DataFrame(d)
df["C"] = [100, 101, 102, 103]
print(df)
df = df.drop("x",axis=0)
print(df)
df = df.drop("B",axis=1)
print(df)
# Out:
#      A   B    C
# w  NaN  80  100
# x  5.0  50  101
# y  6.0  60  102
# z  7.0  70  103
#      A   B    C
# w  NaN  80  100
# y  6.0  60  102
# z  7.0  70  103
#      A    C
# w  NaN  100
# y  6.0  102
# z  7.0  103

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\xvpow\ai_20260426\ch10

# %%
import pandas as pd
df1 = pd.read_csv("ex1.csv")
print(df1)
print("============")
df2 = pd.read_csv("./ex1.csv",header=None)
print(df2)
print("===================")
df3 = pd.read_csv("./ex1.csv",names=["A","B","C","D","E"])
print(df3)
print("===================")
df4 = pd.read_csv("./ex1.csv",index_col="c")
print(df4)
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    good
# ...
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12     good
# ...
#    A   B   C   D        E
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12     good
# ...
#     a   b   d message
# c
# 3   1   2   4   hello
# 7   5   6   8   world
# 11  9  10  12    good

# %%
import pandas as pd
df3a = pd.read_csv("df3a.csv")
print(df3a)
# Out:
#    name  population
# 0   中正區      159598
# 1   板橋區      551452
# 2   桃園區      441287
# 3   北屯區      275207
# 4   安南區      192327
# 5   三民區      343203
# 6   大安區      309835
# 7   永和區      222531
# 8   八德區      198473
# 9   前鎮區      189623
# 10  鳳山區      359125
# 11  信義區      225561
# 12  新店區      302070

# %%
import  pandas as pd
#龘 (音踏)
#犇(音奔)
data={
    'Name':['犇','中文','龘','Ricky'],
    'Age':[28,34,29,42]
}
print(data)
df = pd.DataFrame(data)
print(df)
df.to_html("df1.html")
df.to_csv("df1a.csv")
df.to_csv("df1.csv",index=False)
# Out:
# {'Name': ['犇', '中文', '龘', 'Ricky'], 'Age': [28, 34, 29, 42]}
#     Name  Age
# 0      犇   28
# 1     中文   34
# 2      龘   29
# 3  Ricky   42

# %%
import  pandas as pd
data={
    'Name':['犇','中文','龘','Ricky'],
    'Age':[28,34,29,42]
}
print(data)
df=pd.DataFrame(data)
print(df)
df.to_csv("df1a.csv",index=False,encoding="utf-8")
df.to_csv("df1b.csv",index=False,encoding="utf-8-sig")
# Out:
# {'Name': ['犇', '中文', '龘', 'Ricky'], 'Age': [28, 34, 29, 42]}
#     Name  Age
# 0      犇   28
# 1     中文   34
# 2      龘   29
# 3  Ricky   42

# %% [markdown]
# pip install xlrd

# %%
import  pandas as pd
import  numpy as np
#龘 (音踏)  犇(音奔)
data={
    'Name':['犇','中文','龘','Ricky'],
    'Age':[28,34,29,42]
}
print(data)
df = pd.DataFrame(data)
writer = pd.ExcelWriter("df.xlsx")
df.to_excel(writer,sheet_name="Sheet3")
df1 = pd.DataFrame(np.arange(9).reshape(3,3),
                   index=["a","c","d"],
                  columns=["One","Two","Three"])
df1.to_excel(writer,sheet_name="哈嘍")
writer.close()
# Out:
# {'Name': ['犇', '中文', '龘', 'Ricky'], 'Age': [28, 34, 29, 42]}

# %%
import  pandas as pd
import  numpy as np
df = pd.read_excel("df.xlsx")
print(df)
# Out:
#    Unnamed: 0   Name  Age
# 0           0      犇   28
# 1           1     中文   34
# 2           2      龘   29
# 3           3  Ricky   42

# %% [markdown]
# ### 使用 loc(文字 m:n 會包含到n)
# + "location" 的縮寫
# + .loc[ ], 中括弧裡面是先 row 後 column，以逗號分開。
# + row 與 column 要放入的是 row 標籤與 column 標籤。
# + 可於 row 或 column 加入「：」 ，代表指定起訖範圍。

# %%
import  pandas as pd
import  numpy as np
df = pd.DataFrame(np.arange(48).reshape(6,8),
                 index = ["a","b","c","d","e","f"],
                 columns=["s","t","u","v","w","x","y","z"])
print(df)
print()
s1 = df.loc['b']
print(s1)
print(type(s1))
print(df.loc["b","w"])
print(df.loc[["b","e"],["w","y"]])
s2 = df.loc[["c"]]
print(s2,type(s2))
print(df.loc['c':'e','w':'y'])
print(df.loc[:,'x'])
# Out:
#     s   t   u   v   w   x   y   z
# a   0   1   2   3   4   5   6   7
# b   8   9  10  11  12  13  14  15
# c  16  17  18  19  20  21  22  23
# d  24  25  26  27  28  29  30  31
# e  32  33  34  35  36  37  38  39
# f  40  41  42  43  44  45  46  47
#
# s     8
# t     9
# u    10
# v    11
# w    12
# x    13
# y    14
# z    15
# Name: b, dtype: int64
# <class 'pandas.Series'>
# 12
#     w   y
# b  12  14
# e  36  38
#     s   t   u   v   w   x   y   z
# c  16  17  18  19  20  21  22  23 <class 'pandas.DataFrame'>
#     w   x   y
# c  20  21  22
# d  28  29  30
# e  36  37  38
# a     5
# b    13
# c    21
# d    29
# e    37
# f    45
# Name: x, dtype: int64

# %% [markdown]
# ### 使用 iloc
# + iloc[ ] 與 loc 一樣，中括弧裡面也是先 row 後 column，行列標籤用逗號分開。
# + 與 loc 不同的之處是，.iloc 是根據索引來進行選擇。

# %%
import  pandas as pd
import  numpy as np
df = pd.DataFrame(np.arange(48).reshape(6,8),
                 index = ["a","b","c","d","e","f"],
                 columns=["s","t","u","v","w","x","y","z"])
print(df)
print()
print(df.iloc[1,:])
print()
print(df.iloc[2,4])
print()
print(df.iloc[[2,4],[4,6]])
print(df.iloc[2:4,4:6])
print(df.iloc[:,-2])
# Out:
#     s   t   u   v   w   x   y   z
# a   0   1   2   3   4   5   6   7
# b   8   9  10  11  12  13  14  15
# c  16  17  18  19  20  21  22  23
# d  24  25  26  27  28  29  30  31
# e  32  33  34  35  36  37  38  39
# f  40  41  42  43  44  45  46  47
#
# s     8
# t     9
# u    10
# v    11
# w    12
# x    13
# y    14
# z    15
# Name: b, dtype: int64
#
# 20
#
#     w   y
# c  20  22
# e  36  38
#     w   x
# c  20  21
# d  28  29
# a     6
# b    14
# c    22
# d    30
# e    38
# f    46
# Name: y, dtype: int64

# %%
import  pandas as pd
import  numpy as np
df=pd.DataFrame(
    np.arange(48).reshape(6,8),
    index=['a','b','c','d','e','f'],
    columns=['s','t','u','v','w','x','y','z'])
print(df)

'''
 w   x   y   z
c  20  21  22  23
d  28  29  30  31
e  36  37  38  39
f  44  45  46  47
'''

'''
    s   t   u   v   w   x
a   0   1   2   3   4   5
b   8   9  10  11  12  13
c  16  17  18  19  20  21
d  24  25  26  27  28  29
'''
print(df.loc["c":,"w":])
print(df.loc["a":"d","s":"x"])
print(df.loc["c":"e",["t","u","w"]])
# Out:
#     s   t   u   v   w   x   y   z
# a   0   1   2   3   4   5   6   7
# b   8   9  10  11  12  13  14  15
# c  16  17  18  19  20  21  22  23
# d  24  25  26  27  28  29  30  31
# e  32  33  34  35  36  37  38  39
# f  40  41  42  43  44  45  46  47
#     w   x   y   z
# c  20  21  22  23
# d  28  29  30  31
# e  36  37  38  39
# f  44  45  46  47
#     s   t   u   v   w   x
# a   0   1   2   3   4   5
# b   8   9  10  11  12  13
# c  16  17  18  19  20  21
# d  24  25  26  27  28  29
#     t   u   w
# c  17  18  20
# d  25  26  28
# e  33  34  36

# %%
import  pandas as pd
import  numpy as np
df=pd.DataFrame(
    np.arange(48).reshape(6,8),
    index=['a','b','c','d','e','f'],
    columns=['s','t','u','v','w','x','y','z']
)
print(df)
print("--------")
print(df.iloc[::2,::3])

'''
    t   v   x
b   9  11  13
d  25  27  29
f  41  43  45
'''
print(df.iloc[1::2,1:7:2])
print(df.loc["b"::2,"t":"y":2])
# Out:
#     s   t   u   v   w   x   y   z
# a   0   1   2   3   4   5   6   7
# b   8   9  10  11  12  13  14  15
# c  16  17  18  19  20  21  22  23
# d  24  25  26  27  28  29  30  31
# e  32  33  34  35  36  37  38  39
# f  40  41  42  43  44  45  46  47
# --------
#     s   v   y
# a   0   3   6
# c  16  19  22
# e  32  35  38
#     t   v   x
# b   9  11  13
# d  25  27  29
# f  41  43  45
#     t   v   x
# b   9  11  13
# d  25  27  29
# f  41  43  45

# %%
import  pandas as pd
data_url='http://bit.ly/2cLzoxH'
gap1 = pd.read_csv(data_url)
print(gap1)
is2002 = gap1['year'] == 2002
print(is2002)
data2002 = gap1[is2002]
print(data2002)
queryKey = 1997
gap2 = gap1.query(f"year == {queryKey}")
print(gap2)
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# ...

# %% [markdown]
# ### in 與 not in
#
# + Pandas 有 isin 方法，代表如果資料存在於 isin 方法內的比對對象，那就傳回 True。
# + 如果比對對象是一個 dictionary：
#   + 首先判斷對應的 index 是否存在。
#   + 如果存在，接著判斷對應的位置是否存在。
#   + 如果不存在，那麼全部為 False。
# + 如果是一個 DataFrame：
#   + 首先就是 column 名稱要存在。
#   + 原資料行列位置和對應的行列位置一一匹配，才返回 TRUE。
# + 若要設計一個 not in 的分析語法，請在函數方法前面加個 ~ 即可。

# %%
import  pandas as pd
data_url='http://bit.ly/2cLzoxH'
gap1 = pd.read_csv(data_url)
print(gap1)
data1 = gap1["year"].isin([1997,2007])
print(data1)
data2 = gap1[data1]
print(data2)
data3 = gap1.query("year == 2007 or year == 1997")
print(data3)
print("====================")
data4 = gap1.query("year == 2007 or (year == 1997 and country =='Afghanistan' )")
print(data4)
#2007 或 1997 且country  Afghanistan
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701     True
# ...

# %%
import  pandas as pd
data_url='http://bit.ly/2cLzoxH'
gap1 = pd.read_csv(data_url)
print(gap1)

is1997 = gap1['year'].between(1997,2007)
print(is1997)
data1 =  gap1[is1997]
print(data1)
data2 = gap1.query("year.between(1997,2007)")
print(data2)
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701     True
# ...

# %% [markdown]
# ## 處理日期資訊
# + 可使用 pandas 的 date_range( ) 函數，可以建立日期資料。
# + 默認情況下，範圍的週期單位為天。
# + 若要表達出工作天 (不包含周六周日)，則請選擇 bdate_range( ) 方法。
# + date_range 或 bdate_range( ) 內的參數：
#   + ('起始日期', periods=天數)
#   + periods 由開始日取幾天
#   + ('起始日期','結束日期')
#   + 可加入另外一個參數：freq 代表範圍的週期單位
#
# ![image.png](attachment:8ec2d711-e446-40bd-bc66-56a0b24dd075.png)
#   https://pandas.pydata.org/docs/user_guide/timeseries.html

# %%
import pandas as pd
a = pd.date_range("2026/06/28",periods=10)
print(a)
a = pd.date_range("2026/06/28",periods=10,freq="W")
print(a)
a = pd.date_range("2026/06/28",periods=10,freq="W-MON")
print(a)
# Out:
# DatetimeIndex(['2026-06-28', '2026-06-29', '2026-06-30', '2026-07-01',
#                '2026-07-02', '2026-07-03', '2026-07-04', '2026-07-05',
#                '2026-07-06', '2026-07-07'],
#               dtype='datetime64[us]', freq='D')
# DatetimeIndex(['2026-06-28', '2026-07-05', '2026-07-12', '2026-07-19',
#                '2026-07-26', '2026-08-02', '2026-08-09', '2026-08-16',
#                '2026-08-23', '2026-08-30'],
#               dtype='datetime64[us]', freq='W-SUN')
# DatetimeIndex(['2026-06-29', '2026-07-06', '2026-07-13', '2026-07-20',
#                '2026-07-27', '2026-08-03', '2026-08-10', '2026-08-17',
#                '2026-08-24', '2026-08-31'],
#               dtype='datetime64[us]', freq='W-MON')

# %%
import pandas as pd
from  datetime import  date
start = date(2026,6,28)
end = date(2026,12,30)
a = pd.date_range(start,end)
c = pd.date_range(start,end,freq = "W")
d = pd.date_range(start,end,freq = "ME")
print(a)
print(c)
print(d)
# Out:
# DatetimeIndex(['2026-06-28', '2026-06-29', '2026-06-30', '2026-07-01',
#                '2026-07-02', '2026-07-03', '2026-07-04', '2026-07-05',
#                '2026-07-06', '2026-07-07',
#                ...
#                '2026-12-21', '2026-12-22', '2026-12-23', '2026-12-24',
#                '2026-12-25', '2026-12-26', '2026-12-27', '2026-12-28',
#                '2026-12-29', '2026-12-30'],
#               dtype='datetime64[s]', length=186, freq='D')
# DatetimeIndex(['2026-06-28', '2026-07-05', '2026-07-12', '2026-07-19',
#                '2026-07-26', '2026-08-02', '2026-08-09', '2026-08-16',
#                '2026-08-23', '2026-08-30', '2026-09-06', '2026-09-13',
#                '2026-09-20', '2026-09-27', '2026-10-04', '2026-10-11',
#                '2026-10-18', '2026-10-25', '2026-11-01', '2026-11-08',
#                '2026-11-15', '2026-11-22', '2026-11-29', '2026-12-06',
#                '2026-12-13', '2026-12-20', '2026-12-27'],
# ...

# %%
import pandas as pd
from  datetime import  date
import  numpy as np
dates = pd.date_range("20260628",periods=200)
print(dates)
se = pd.Series(np.arange(1,201),index = dates)
print(se)
se.to_csv("se.csv")
se_1 = se.sum()
print(se_1)
se_2 = se.resample("ME").sum()
print(se_2)
se_3 = se.resample("QE").sum()
print(se_3)
# Out:
# DatetimeIndex(['2026-06-28', '2026-06-29', '2026-06-30', '2026-07-01',
#                '2026-07-02', '2026-07-03', '2026-07-04', '2026-07-05',
#                '2026-07-06', '2026-07-07',
#                ...
#                '2027-01-04', '2027-01-05', '2027-01-06', '2027-01-07',
#                '2027-01-08', '2027-01-09', '2027-01-10', '2027-01-11',
#                '2027-01-12', '2027-01-13'],
#               dtype='datetime64[us]', length=200, freq='D')
# 2026-06-28      1
# 2026-06-29      2
# 2026-06-30      3
# 2026-07-01      4
# 2026-07-02      5
#              ...
# 2027-01-09    196
# 2027-01-10    197
# 2027-01-11    198
# 2027-01-12    199
# 2027-01-13    200
# Freq: D, Length: 200, dtype: int64
# 20100
# 2026-06-30       6
# 2026-07-31     589
# 2026-08-31    1550
# 2026-09-30    2415
# 2026-10-31    3441
# 2026-11-30    4245
# 2026-12-31    5332
# 2027-01-31    2522
# Freq: ME, dtype: int64
# 2026-06-30        6
# 2026-09-30     4554
# 2026-12-31    13018
# ...

# %%
import pandas as pd
se2 = pd.read_csv("se2.csv",index_col="Date",names=["Date","num"])
print(se2.index)
se2M = se2.resample("ME").sum()
print(se2M)
# Out:
# Index(['2023/5/28', '2023/5/29', '2023/5/30', '2023/5/31', '2023/6/1',
#        '2023/6/2', '2023/6/3', '2023/6/4', '2023/6/5', '2023/6/6',
#        ...
#        '2023/12/4', '2023/12/5', '2023/12/6', '2023/12/7', '2023/12/8',
#        '2023/12/9', '2023/12/10', '2023/12/11', '2023/12/12', '2023/12/13'],
#       dtype='str', name='Date', length=200)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 4
#       2 se2 = pd.read_csv("se2.csv",index_col="Date",names=["Date","num"])
#       3 print(se2.index)
# ----> 4 se2M = se2.resample("ME").sum()
#       5 print(se2M)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9068 """
#    9069 Resample time-series data.
#    9070
#    (...)   9419 Freq: 17min, dtype: int64
#    9420 """
# ...

# %%
import pandas as pd
se2 = pd.read_csv("se2.csv",names=["Date","num"])
print(se2)
print(se2.index)
print(se2.dtypes)
se2["Date"] = pd.to_datetime(se2["Date"])
print(se2.dtypes)
se2.set_index("Date",inplace=True)
print(se2.index)
se2M = se2.resample("ME").sum()
print(se2M)
# Out:
#            Date  num
# 0     2023/5/28    1
# 1     2023/5/29    2
# 2     2023/5/30    3
# 3     2023/5/31    4
# 4      2023/6/1    5
# ..          ...  ...
# 195   2023/12/9  196
# 196  2023/12/10  197
# 197  2023/12/11  198
# 198  2023/12/12  199
# 199  2023/12/13  200
#
# [200 rows x 2 columns]
# RangeIndex(start=0, stop=200, step=1)
# Date      str
# num     int64
# dtype: object
# Date    datetime64[us]
# num              int64
# dtype: object
# DatetimeIndex(['2023-05-28', '2023-05-29', '2023-05-30', '2023-05-31',
#                '2023-06-01', '2023-06-02', '2023-06-03', '2023-06-04',
#                '2023-06-05', '2023-06-06',
#                ...
#                '2023-12-04', '2023-12-05', '2023-12-06', '2023-12-07',
#                '2023-12-08', '2023-12-09', '2023-12-10', '2023-12-11',
#                '2023-12-12', '2023-12-13'],
#               dtype='datetime64[us]', name='Date', length=200, freq=None)
#              num
# Date
# 2023-05-31    10
# ...

# %% [markdown]
# ## 判斷遺失值產生原因
# + 有些資訊是暫時無法讀取。
# + 有些資訊是被遺漏。
# + 有些對象的某些屬性特徵是不存在。
# + 有些資訊被認為不重要。
# + 操作這些資訊的代價太大而被遺棄。

# %%
import pandas as pd
import  numpy as np
from io import  StringIO
csv_data='''
A,B,C,D
1.0,2.0,x,4
5.5,34,3.4,x
10,x,11.5,8.5
'''
data3 = pd.read_csv(StringIO(csv_data))
print(data3)
print("count:",data3.count())
#print(data3.mean())
print(data3.isnull().any())
print(data3.isnull().sum())
data3.replace("x",np.nan,inplace=True)
print(data3)
print("count:",data3.count())
print("dtypes:",data3.dtypes)
#print("mean:",data3.mean())
print(data3.isnull().any())
print(data3.isnull().sum())
# Out:
#       A    B     C    D
# 0   1.0  2.0     x    4
# 1   5.5   34   3.4    x
# 2  10.0    x  11.5  8.5
# count: A    3
# B    3
# C    3
# D    3
# dtype: int64
# A    False
# B    False
# C    False
# D    False
# dtype: bool
# A    0
# B    0
# C    0
# D    0
# dtype: int64
#       A    B     C    D
# 0   1.0  2.0   NaN    4
# 1   5.5   34   3.4  NaN
# 2  10.0  NaN  11.5  8.5
# count: A    3
# B    2
# C    2
# D    2
# dtype: int64
# dtypes: A    float64
# B        str
# C        str
# D        str
# dtype: object
# A    False
# B     True
# C     True
# D     True
# dtype: bool
# A    0
# B    1
# C    1
# D    1
# dtype: int64

# %%
import pandas as pd
import  numpy as np
from io import  StringIO
csv_data='''
A,B,C,D
1.0,2.0,x,4
5.5,34,3.4,x
10,x,11.5,8.5
'''
data3 = pd.read_csv(StringIO(csv_data))
print(data3)
data3 = data3.replace("x",np.nan)
print(data3)
print(data3.info())
for x in data3:
    if data3[x].dtype == 'str':
        data3[x]= data3[x].astype('float64')
data3.info()
data3.mean()
# Out:
#       A    B     C    D
# 0   1.0  2.0     x    4
# 1   5.5   34   3.4    x
# 2  10.0    x  11.5  8.5
#       A    B     C    D
# 0   1.0  2.0   NaN    4
# 1   5.5   34   3.4  NaN
# 2  10.0  NaN  11.5  8.5
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      float64
#  1   B       2 non-null      str
#  2   C       2 non-null      str
#  3   D       2 non-null      str
# dtypes: float64(1), str(3)
# memory usage: 247.0 bytes
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      float64
#  1   B       2 non-null      float64
#  2   C       2 non-null      float64
#  3   D       2 non-null      float64
# dtypes: float64(4)
# memory usage: 228.0 bytes
# A     5.50
# B    18.00
# C     7.45
# ...

# %% [markdown]
# ## 丟棄遺失值
# + 您可以使用 dropna 方法再搭配 axis 參數方式進行搭配。
# + 默認情況下，預設為 axis = 0，也就是會沿著 Rows 進行，當發現到任何值為 NA 就會整個 Row 刪除。
# + 若加入參數 how=‘all’ 代表整個 Row 資料都是遺失值情況下才可以刪除丟棄。
# + 加入參數 thresh=N 代表刪除包含少於 N 個觀察值的 row。

# %%
import pandas as pd
import  numpy as np
from io import  StringIO
csv_data='''
A,B,C,D,E
2,3,4,5,
6,34,6,
10,,11,8,
,,,
3,,3,,
,5,,,
'''
drop=pd.read_csv(StringIO(csv_data))
print(drop)
drop1 = drop.dropna(axis=0)
print(drop1)
drop2 = drop.dropna(axis=1)
print(drop2)
drop3 = drop.dropna(axis=0,how="all")# 所有都是Nan才移除
print(drop3)
drop4 = drop.dropna(axis=1,how="all")
print(drop4)
# Out:
#       A     B     C    D   E
# 0   2.0   3.0   4.0  5.0 NaN
# 1   6.0  34.0   6.0  NaN NaN
# 2  10.0   NaN  11.0  8.0 NaN
# 3   NaN   NaN   NaN  NaN NaN
# 4   3.0   NaN   3.0  NaN NaN
# 5   NaN   5.0   NaN  NaN NaN
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]
#       A     B     C    D   E
# 0   2.0   3.0   4.0  5.0 NaN
# 1   6.0  34.0   6.0  NaN NaN
# 2  10.0   NaN  11.0  8.0 NaN
# 4   3.0   NaN   3.0  NaN NaN
# 5   NaN   5.0   NaN  NaN NaN
#       A     B     C    D
# 0   2.0   3.0   4.0  5.0
# 1   6.0  34.0   6.0  NaN
# 2  10.0   NaN  11.0  8.0
# 3   NaN   NaN   NaN  NaN
# 4   3.0   NaN   3.0  NaN
# 5   NaN   5.0   NaN  NaN

# %%
import pandas as pd
import  numpy as np
from io import  StringIO
csv_data='''
A,B,C,D,E
2,3,4,5,
6,34,6,
10,,11,8,
,,,
3,,3,,
,5,,,
'''
drop=pd.read_csv(StringIO(csv_data))
print(drop)
drop1 = drop.dropna(thresh=3)#非缺失值(有數值的)<thresh移除 至少要有 thresh 個有效資料才保留
print(drop1)
drop2 = drop.dropna(thresh=3,axis=1)
print(drop2)
# Out:
#       A     B     C    D   E
# 0   2.0   3.0   4.0  5.0 NaN
# 1   6.0  34.0   6.0  NaN NaN
# 2  10.0   NaN  11.0  8.0 NaN
# 3   NaN   NaN   NaN  NaN NaN
# 4   3.0   NaN   3.0  NaN NaN
# 5   NaN   5.0   NaN  NaN NaN
#       A     B     C    D   E
# 0   2.0   3.0   4.0  5.0 NaN
# 1   6.0  34.0   6.0  NaN NaN
# 2  10.0   NaN  11.0  8.0 NaN
#       A     B     C
# 0   2.0   3.0   4.0
# 1   6.0  34.0   6.0
# 2  10.0   NaN  11.0
# 3   NaN   NaN   NaN
# 4   3.0   NaN   3.0
# 5   NaN   5.0   NaN
